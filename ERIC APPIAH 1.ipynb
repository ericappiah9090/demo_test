# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __ERIC NKANSAH APPIAH__
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because i want to help businesses solve problems and make better decisions. I have a passion for using data to draw meaningful conclusions about a company's growth*

# %% [markdown]
# ### The below should print "I love data science"

# %%
print("I love data science")
# Out:
# I love data science

# %% [markdown]
# ---
# ---
# *
# *
# 1.
# 2.
